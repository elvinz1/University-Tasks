# %% [markdown]
# <a href="https://colab.research.google.com/github/elvinz1/University-Tasks/blob/main/BA_Homework_Python2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Case Intro
# Term deposits are a major source of income for a bank. A term deposit is a cash investment held at a financial institution. Your money is invested for an agreed rate of interest over a fixed amount of time, or term. The bank has various outreach plans to sell term deposits to their customers such as email marketing, advertisements, telephonic marketing, and digital marketing.
#
# Telephonic marketing campaigns still remain one of the most effective way to reach out to people. However, they require huge investment as large call centers are hired to actually execute these campaigns. Hence, it is crucial to identify the customers most likely to convert beforehand so that they can be specifically targeted via call.
#
# The data is related to direct marketing campaigns (phone calls) of a Portuguese banking institution. The classification goal is to predict if the client will subscribe to a term deposit (variable y).
#
# Content
# The data is related to the direct marketing campaigns of a Portuguese banking institution. The marketing campaigns were based on phone calls. Often, more than one contact to the same client was required, in order to access if the product (bank term deposit) would be ('yes') or not ('no') subscribed by the customer or not. The data folder contains two datasets:-
#
# Bank.csv: 45,211 rows and 18 columns ordered by date (from May 2008 to November 2010)
#
# Detailed Column Descriptions
# bank client data:
#
# 1 - age (numeric)
#
# 2 - job : type of job (categorical: "admin.","unknown","unemployed","management","housemaid","entrepreneur","student",
# "blue-collar","self-employed","retired","technician","services")
#
# 3 - marital : marital status (categorical: "married","divorced","single"; note: "divorced" means divorced or widowed)
#
# 4 - education (categorical: "unknown","secondary","primary","tertiary")
#
# 5 - default: has credit in default? (binary: "yes","no")
#
# 6 - balance: average yearly balance, in euros (numeric)
#
# 7 - housing: has housing loan? (binary: "yes","no")
#
# 8 - loan: has personal loan? (binary: "yes","no")
# # related with the last contact of the current campaign:
# 9 - contact: contact communication type (categorical: "unknown","telephone","cellular")
# 10 - day: last contact day of the month (numeric)
#
# 11 - month: last contact month of year (categorical: "jan", "feb", "mar", …, "nov", "dec")
#
# 12 - duration: last contact duration, in seconds (numeric)
#
# # other attributes:
# 13 - campaign: number of contacts performed during this campaign and for this client (numeric, includes last contact)
#
# 14 - pdays: number of days that passed by after the client was last contacted from a previous campaign (numeric, -1 means client was not previously contacted)
#
# 15 - previous: number of contacts performed before this campaign and for this client (numeric)
#
# 16 - poutcome: outcome of the previous marketing campaign (categorical: "unknown","other","failure","success")
#
# Output variable (desired target):
#
# 17 - y - has the client subscribed a term deposit? (binary: "yes","no")
#
# Missing Attribute Values: None

# %%
#Q0
import pandas as pd
import numpy as np
#if the data is in the ('https://raw.githubusercontent.com/ogut77/DataScience/main/data/Bank.csv',sep = ';')
#read the data and name df

data = pd.read_csv('https://raw.githubusercontent.com/ogut77/DataScience/main/data/Bank.csv',sep = ';')
df = pd.DataFrame(data)
df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
#Q1-Find the shape rows and column of data
data = pd.read_csv('https://raw.githubusercontent.com/ogut77/DataScience/main/data/Bank.csv',sep = ';')
df = pd.DataFrame(data)
print(df.shape)
# Out:
# (45211, 17)

# %%
#Q2-Get first two rows  of data
data = pd.read_csv('https://raw.githubusercontent.com/ogut77/DataScience/main/data/Bank.csv',sep = ';')
df = pd.DataFrame(data)
df1=df.head(2)
df1
# Out:
#    age         job  marital  education default  balance housing loan  contact  \
# 0   58  management  married   tertiary      no     2143     yes   no  unknown
# 1   44  technician   single  secondary      no       29     yes   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome   y
# 0    5   may       261         1     -1         0  unknown  no
# 1    5   may       151         1     -1         0  unknown  no

# %%
#Q3-Get last three rows of data
data = pd.read_csv('https://raw.githubusercontent.com/ogut77/DataScience/main/data/Bank.csv',sep = ';')
df = pd.DataFrame(data)
df1=df.tail(3)
df1
# Out:
#        age           job  marital  education default  balance housing loan  \
# 45208   72       retired  married  secondary      no     5715      no   no
# 45209   57   blue-collar  married  secondary      no      668      no   no
# 45210   37  entrepreneur  married  secondary      no     2971      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome    y
# 45208   cellular   17   nov      1127         5    184         3  success  yes
# 45209  telephone   17   nov       508         4     -1         0  unknown   no
# 45210   cellular   17   nov       361         2    188        11    other   no

# %%
#Q4-Get column names
data = pd.read_csv('https://raw.githubusercontent.com/ogut77/DataScience/main/data/Bank.csv',sep = ';')
df = pd.DataFrame(data)
print(df.keys())
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
#Q5-Get Print a concise summary of a DataFrame df such as
#column name, data type  and number of rows and columns
data = pd.read_csv('https://raw.githubusercontent.com/ogut77/DataScience/main/data/Bank.csv',sep = ';')
df = pd.DataFrame(data)
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  y          45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB
# None

# %%
#Q6-Get descriptive statistics of numeric data
data = pd.read_csv('https://raw.githubusercontent.com/ogut77/DataScience/main/data/Bank.csv',sep = ';')
df = pd.DataFrame(data)
df.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419    258.163080      2.763841
# std       10.618762    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %%
#Q7-Get descriptive statistics of non-numeric object type of data
import pandas as pd
import numpy as np

df = pd.read_csv('https://raw.githubusercontent.com/ogut77/DataScience/main/data/Bank.csv',sep = ';')
columns = df[['job',	'marital',	'education',	'default',	'housing',	'loan',	'contact',	'month',	'poutcome',	'y']]
stats = columns.describe(include='O')
stats
# Out:
#                 job  marital  education default housing   loan   contact  \
# count         45211    45211      45211   45211   45211  45211     45211
# unique           12        3          4       2       2      2         3
# top     blue-collar  married  secondary      no     yes     no  cellular
# freq           9732    27214      23202   44396   25130  37967     29285
#
#         month poutcome      y
# count   45211    45211  45211
# unique     12        4      2
# top       may  unknown     no
# freq    13766    36959  39922

# %%
#Q8-Get the mean of campain column only
data = pd.read_csv('https://raw.githubusercontent.com/ogut77/DataScience/main/data/Bank.csv',sep = ';')
df = pd.DataFrame(data)
df["campaign"].mean()
# Out:
# 2.763840658246887

# %%
#Q9-Print correlation matrix
import pandas as pd

data = pd.read_csv('https://raw.githubusercontent.com/ogut77/DataScience/main/data/Bank.csv',sep = ';')
df = pd.DataFrame(data)
df.corr()
# Out:
#                age   balance       day  duration  campaign     pdays  previous
# age       1.000000  0.097783 -0.009120 -0.004648  0.004760 -0.023758  0.001288
# balance   0.097783  1.000000  0.004503  0.021560 -0.014578  0.003435  0.016674
# day      -0.009120  0.004503  1.000000 -0.030206  0.162490 -0.093044 -0.051710
# duration -0.004648  0.021560 -0.030206  1.000000 -0.084570 -0.001565  0.001203
# campaign  0.004760 -0.014578  0.162490 -0.084570  1.000000 -0.088628 -0.032855
# pdays    -0.023758  0.003435 -0.093044 -0.001565 -0.088628  1.000000  0.454820
# previous  0.001288  0.016674 -0.051710  0.001203 -0.032855  0.454820  1.000000

# %%
#Q10-Count the frequency values of y
import pandas as pd

data = pd.read_csv('https://raw.githubusercontent.com/ogut77/DataScience/main/data/Bank.csv',sep = ';')
df = pd.DataFrame(data)
pd.Series(df['y']).value_counts()
# Out:
# no     39922
# yes     5289
# Name: y, dtype: int64

# %%
#Q11-Count the frequency values of education in terms of percenage
import pandas as pd

data = pd.read_csv('https://raw.githubusercontent.com/ogut77/DataScience/main/data/Bank.csv',sep = ';')
df = pd.DataFrame(data)
value_counts = df['education'].value_counts()
percentages = value_counts.apply(lambda x: x / len(df) )
print(percentages)
# Out:
# secondary    0.513194
# tertiary     0.294198
# primary      0.151534
# unknown      0.041074
# Name: education, dtype: float64

# %%
#Q12- Select rows with education 'secondary' or 'tertiary'
#and assign into dataframe named ST and print first 5 columns of ST.
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 5   35    management  married   tertiary      no      231     yes   no
# 6   28    management   single   tertiary      no      447     yes  yes
#
#    contact  day month  duration  campaign  pdays  previous poutcome  y
# 0  unknown    5   may       261         1     -1         0  unknown  0
# 1  unknown    5   may       151         1     -1         0  unknown  0
# 2  unknown    5   may        76         1     -1         0  unknown  0
# 5  unknown    5   may       139         1     -1         0  unknown  0
# 6  unknown    5   may       217         1     -1         0  unknown  0

# %%
#Q13- Select rows with education 'secondary' and job is 'management'
#and assign into dataframe named SM and print first 5 columns of SM.
# Out:
#     age         job   marital  education default  balance housing loan  \
# 28   46  management    single  secondary      no     -246     yes   no
# 41   50  management   married  secondary      no       49     yes   no
# 72   54  management   married  secondary      no      282     yes  yes
# 88   46  management  divorced  secondary      no       16     yes  yes
# 90   42  management    single  secondary      no       50      no   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome  y
# 28  unknown    5   may       255         2     -1         0  unknown  0
# 41  unknown    5   may       180         2     -1         0  unknown  0
# 72  unknown    5   may       154         1     -1         0  unknown  0
# 88  unknown    5   may       188         2     -1         0  unknown  0
# 90  unknown    5   may        48         1     -1         0  unknown  0

# %%
#Q14-Get age and balance column and assign into dataframe named AB
# Out:
#        age  balance
# 0       58     2143
# 1       44       29
# 2       33        2
# 3       47     1506
# 4       33        1
# ...    ...      ...
# 45206   51      825
# 45207   71     1729
# 45208   72     5715
# 45209   57      668
# 45210   37     2971
#
# [45211 rows x 2 columns]

# %%
#Q15-Create column named total by adding campaing and previous columns.

# %%
#Q16-Get first two column and 3 rows of data
# Out:
#    age           job
# 0   58    management
# 1   44    technician
# 2   33  entrepreneur

# %%
#Q17-Replace yes to 1 and no to 0 for column y
# Out:
# 0    39922
# 1     5289
# Name: y, dtype: int64

# %%
#Q18-Assign df['y'] column to y and rest of the columns to X
# Out:
#        age  job  marital  education  default  balance  housing  loan  contact  \
# 0       58    4        1          2        0     2143        1     0        2
# 1       44    9        2          1        0       29        1     0        2
# 2       33    2        1          1        0        2        1     1        2
# 3       47    1        1          3        0     1506        1     0        2
# 4       33   11        2          3        0        1        0     0        2
# ...    ...  ...      ...        ...      ...      ...      ...   ...      ...
# 45206   51    9        1          2        0      825        0     0        0
# 45207   71    5        0          0        0     1729        0     0        0
# 45208   72    5        1          1        0     5715        0     0        0
# 45209   57    1        1          1        0      668        0     0        1
# 45210   37    2        1          1        0     2971        0     0        0
#
# ...

# %%
#Q19-Complete the following line with comment
a=-3
if a>0:#Complete this line
  print("This is positive number")
elif a<0:#Complete this line
  print("This is negative number")
else :#Complete this line
  print("This is zero")
# Out:
# This is negative number

# %%
#Q20-Complet following code to determine the number is multiple of 5 or not.
#Hint you can use modulus(%) statement
a=7
b= a%5
if b==0:#Complete this line
  print('Number is multiple of 5')
else:#Complete this line
  print('Number is not multiple of 5')
# Out:
# Number is not multiple of 5

# %%
#Q21: What is the outcome of following code
for i in range(5,0,-1):
   print(i)
# Out:
# 5
# 4
# 3
# 2
# 1
